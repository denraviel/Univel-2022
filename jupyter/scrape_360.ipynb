# %%
import bs4
import requests

# %%
soup = bs4.BeautifulSoup

# %%
response = requests.get("https://hub360.com.ng/")

# %%
categories = soup(response.text).find("ul", {"id":"category-menu"})

# %%
category_2 = soup(response.text).find_all("span")
category_2
# Out:
# [<span style="display:block;overflow:hidden;width:2px;height:2px;"> As sex doll reviewers, we’ve tested the products on hundreds of love dolls and have experienced both the advantages and disadvantages of buying <a href="https://www.littlesexdoll.com/product-category/shemale-sex-doll/">shemale sex doll</a>. </span>,
#  <span class="mini-cart-items cart-mobile">0</span>,
#  <span class="icon">
#  <i class="icon-basket icons"></i>
#  <span class="count mini-cart-items cart-mobile">0</span>
#                      View Cart                </span>,
#  <span class="count mini-cart-items cart-mobile">0</span>,
#  <span class="icon">
#  <i class="icon-heart icons"></i>
#  <span class="count count_wishlist">0</span>
#                  Wishlist            </span>,
#  <span class="count count_wishlist">0</span>,
#  <span aria-hidden="true">×</span>,
#  <span class="fa fa-user"></span>,
#  <span class="fa fa-shopping-cart"></span>,
#  <span class="text-skin cart-icon">
# ...
